# %% [markdown]
# <a href="https://colab.research.google.com/github/arcursino/FATEC/blob/master/gini_idh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
#files.upload()

from google.colab import auth, drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/gdrive/My Drive/gini/gini-idh.csv')

# %%
df.shape
# Out:
# (16695, 7)

# %%
df.groupbydescribe()
# Out:
#                 ANO          GINI          PIND          RIND         THEIL  \
# count  16695.000000  16695.000000  16695.000000  16695.000000  16695.000000
# mean    2000.333333      0.522299     21.017803     37.424227      0.486604
# std        7.760530      0.072264     18.869793      9.778168      0.142862
# min     1991.000000      0.270000      0.000000      0.000000      0.120000
# 25%     1991.000000      0.470000      4.590000     31.715000      0.390000
# 50%     2000.000000      0.520000     15.440000     38.070000      0.470000
# 75%     2010.000000      0.570000     33.775000     44.000000      0.560000
# max     2010.000000      0.920000     92.700000     70.000000      3.230000
#
#                IDHM
# count  16695.000000
# mean       0.521825
# std        0.147558
# min        0.120000
# 25%        0.410000
# 50%        0.540000
# 75%        0.640000
# max        0.860000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16695 entries, 0 to 16694
# Data columns (total 7 columns):
# ANO          16695 non-null int64
# Município    16695 non-null object
# GINI         16695 non-null float64
# PIND         16695 non-null float64
# RIND         16695 non-null float64
# THEIL        16695 non-null float64
# IDHM         16695 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 913.1+ KB

# %%
df.head()
# Out:
#     ANO              Município  GINI   PIND   RIND  THEIL  IDHM
# 0  1991  ALTA FLORESTA D'OESTE  0.63  39.21  36.83   0.73  0.33
# 1  1991              ARIQUEMES  0.57  18.90  40.20   0.59  0.43
# 2  1991                 CABIXI  0.70  60.76  21.11   0.72  0.31
# 3  1991                 CACOAL  0.66  24.76  34.42   0.79  0.41
# 4  1991             CEREJEIRAS  0.60  27.56  38.46   0.64  0.39

# %%
df.isnull().sum()
# Out:
# ANO          0
# Município    0
# GINI         0
# PIND         0
# RIND         0
# THEIL        0
# IDHM         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ANO', 'Município', 'GINI', 'PIND', 'RIND', 'THEIL', 'IDHM'], dtype='object')

# %% [markdown]
# GINI = Coeficiente de Gini (Mede o grau de desigualdade existente na distribuição de indivíduos segundo a renda domiciliar per capita) /
# PINDI = Proporção de extremamente pobres. /
# RIND = Renda domiciliar per capita média dos extremamente pobres. /
# THEIL = Indíce de Theil (Mede a desigualdade na distribuição de indivíduos segundo a renda domiciliar per capita). /
# IDHM = Indíce de Desenvolvimento Humano Municipal (Média geométrica dos índices das dimensões Renda, Educação e Longevidade, com pesos iguais).

# %%
df.head()
# Out:
#     ANO              Município  GINI   PIND   RIND  THEIL  IDHM
# 0  1991  ALTA FLORESTA D'OESTE  0.63  39.21  36.83   0.73  0.33
# 1  1991              ARIQUEMES  0.57  18.90  40.20   0.59  0.43
# 2  1991                 CABIXI  0.70  60.76  21.11   0.72  0.31
# 3  1991                 CACOAL  0.66  24.76  34.42   0.79  0.41
# 4  1991             CEREJEIRAS  0.60  27.56  38.46   0.64  0.39

# %% [markdown]
#  Logo, a correlação também é outra medida que indica o quanto duas variáveis estão relacionadas. Seu valor fica sempre entre -1, que indica uma anti-correlação perfeita, e 1, que indica uma correlação perfeita.

# %%
df['GINI'].corr(df['IDHM'])
# Out:
# -0.2182162578717741

# %%
df['GINI'].corr(df['PIND'])
# Out:
# 0.33408389603534255

# %%
df['GINI'].corr(df['RIND'])
# Out:
# -0.10177684646988508

# %%
df['GINI'].corr(df['THEIL'])
# Out:
# 0.9313190685161555

# %%
df.corr('spearman')
# Out:
#             ANO      GINI      PIND      RIND     THEIL      IDHM
# ANO    1.000000 -0.178395 -0.431270 -0.481885 -0.090416  0.777302
# GINI  -0.178395  1.000000  0.401490 -0.124368  0.950520 -0.250905
# PIND  -0.431270  0.401490  1.000000 -0.188422  0.323978 -0.838488
# RIND  -0.481885 -0.124368 -0.188422  1.000000 -0.097210 -0.125987
# THEIL -0.090416  0.950520  0.323978 -0.097210  1.000000 -0.140030
# IDHM   0.777302 -0.250905 -0.838488 -0.125987 -0.140030  1.000000

# %% [markdown]
# Covariância é uma medida numérica que indica a inter-dependência entre duas variáveis. A covariância indica como duas variáveis se comportam conjuntamente em relação às suas médias. Uma covariância igual a 0 indica que as duas variáveis são totalmente independentes.

# %%
print(df.cov())
# Out:
#              ANO      GINI        PIND       RIND     THEIL      IDHM
# ANO    60.225830 -0.102541  -62.268987 -32.859719 -0.111879  0.879253
# GINI   -0.102541  0.005222    0.455560  -0.071917  0.009615 -0.002327
# PIND  -62.268987  0.455560  356.069079 -31.980982  0.624441 -2.302509
# RIND  -32.859719 -0.071917  -31.980982  95.612572 -0.077239 -0.179339
# THEIL  -0.111879  0.009615    0.624441  -0.077239  0.020410 -0.002181
# IDHM    0.879253 -0.002327   -2.302509  -0.179339 -0.002181  0.021773

# %%
import seaborn as sns
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
pd.scatter_matrix(df, alpha = 0.3, figsize = (14,8), diagonal = 'kde');
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
sns.pairplot(df)

# %%
import pandas as pd
import numpy as np

rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_cc581342_03a1_11e9_a6a0_0242ac1c0002row0_col0 {
#             background-color:  #023858;
#         }    #T_cc581342_03a1_11e9_a6a0_0242ac1c0002row0_col1 {
#             background-color:  #69a5cc;
#         }    #T_cc581342_03a1_11e9_a6a0_0242ac1c0002row0_col2 {
#             background-color:  #3f93c2;
#         }    #T_cc581342_03a1_11e9_a6a0_0242ac1c0002row0_col3 {
#             background-color:  #2f8bbe;
#         }    #T_cc581342_03a1_11e9_a6a0_0242ac1c0002row0_col4 {
#             background-color:  #91b5d6;
#         }    #T_cc581342_03a1_11e9_a6a0_0242ac1c0002row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_cc581342_03a1_11e9_a6a0_0242ac1c0002row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_cc581342_03a1_11e9_a6a0_0242ac1c0002row0_col7 {
#             background-color:  #2987bc;
#         }    #T_cc581342_03a1_11e9_a6a0_0242ac1c0002row0_col8 {
#             background-color:  #efe9f3;
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
df['IDHM'].value_counts().plot(kind = 'bar')

# %%
red = mpatches.Patch(color='red', label='IDHM')
blue = mpatches.Patch(color = 'blue', label = 'GINI')
